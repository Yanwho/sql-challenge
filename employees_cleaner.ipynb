# %%
import pandas as pd

file_to_load = "EmployeeSQL/employees.csv"

employees = pd.read_csv(file_to_load)
employees_df = pd.DataFrame(employees)

# %%
employees_df
# Out:
#         emp_no emp_title_id  birth_date   first_name  last_name sex  \
# 0       473302        s0001   7/25/1953     Hideyuki   Zallocco   M
# 1       475053        e0002  11/18/1954        Byong  Delgrande   F
# 2        57444        e0002   1/30/1958        Berry       Babb   F
# 3       421786        s0001   9/28/1957        Xiong   Verhoeff   M
# 4       282238        e0003  10/28/1952   Abdelkader    Baumann   F
# ...        ...          ...         ...          ...        ...  ..
# 300019  464231        s0001   8/14/1958  Constantino    Eastman   M
# 300020  255832        e0002    5/8/1955       Yuping     Dayang   F
# 300021   76671        s0001    6/9/1959       Ortrud   Plessier   M
# 300022  264920        s0001   9/22/1959        Percy   Samarati   F
# 300023  464503        s0002   5/31/1964       Arvind  Slobodova   M
#
#          hire_date
# 0        4/28/1990
# 1         9/7/1991
# 2        3/21/1992
# 3       11/26/1987
# 4        1/18/1991
# ...            ...
# ...

# %%
# pd.to_datetime(employees_df["birth_date"])
employees_df["birth_date"] = (employees_df["birth_date"].dt.strftime('%m-%d-%Y'))
employees_df["birth_date"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-3d33199731a6> in <module>
#       1 # pd.to_datetime(employees_df["birth_date"])
# ----> 2 employees_df["birth_date"] = (employees_df["birth_date"].dt.strftime('%m-%d-%Y'))
#       3 employees_df["birth_date"]
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
# ...

# %%
employees_df["hire_date"] = (employees_df["hire_date"].dt.strftime('%m-%d-%Y'))
# employees_df_1 = employees_df["hire_date"].dt.strftime('%m-%d-%Y')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-9ec22f7debc6> in <module>
# ----> 1 employees_df["hire_date"] = (employees_df["hire_date"].dt.strftime('%m-%d-%Y'))
#       2 # employees_df_1 = employees_df["hire_date"].dt.strftime('%m-%d-%Y')
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
# ...

# %%
employees_clean = pd.DataFrame(employees_df)
# employees_clean.to_csv("employees_clean.csv", index=False)
employees_clean
